# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Building Refurbishment Services</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 0;
            line-height: 1.6;
        }

        header {
            background: #333;
            color: #fff;
            padding: 1rem 0;
            text-align: center;
        }

        header h1 {
            margin: 0;
            font-size: 2rem;
        }

        nav {
            background: #444;
            display: flex;
            justify-content: center;
            padding: 0.5rem 0;
        }

        nav a {
            color: #fff;
            text-decoration: none;
            margin: 0 1rem;
        }

        nav a:hover {
            text-decoration: underline;
        }

        .section {
            padding: 2rem;
            text-align: center;
        }

        .about {
            background: #f4f4f4;
        }

        .projects {
            background: #e2e2e2;
        }

        footer {
            background: #333;
            color: #fff;
            text-align: center;
            padding: 1rem 0;
        }
    </style>
</head>
<body>
    <header>
        <h1>Building Refurbishment & Reconstruction</h1>
    </header>

    <nav>
        <a href="#home">Home</a>
        <a href="#about">About Me</a>
        <a href="#projects">Projects</a>
        <a href="#contact">Contact</a>
    </nav>

    <section id="home" class="section">
        <h2>Welcome to Our Services</h2>
        <p>We specialize in rebuilding and refurbishing buildings with precision and care. Let us transform your space!</p>
    </section>

    <section id="about" class="section about">
        <h2>About Me</h2>
        <p>With years of experience in building refurbishment and reconstruction, we provide top-notch services tailored to your needs.</p>
    </section>

    <section id="projects" class="section projects">
        <h2>Our Projects</h2>
        <p>Explore our portfolio to see our craftsmanship in action.</p>
    </section>

    <section id="contact" class="section">
        <h2>Contact Us</h2>
        <p>Reach out to us for your next project. Call us at (123) 456-7890 or email us at info@example.com.</p>
    </section>

    <footer>
        <p>&copy; 2024 Building Refurbishment Services. All Rights Reserved.</p>
    </footer>
</body>
</html>
